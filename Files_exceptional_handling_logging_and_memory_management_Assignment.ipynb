# %% [markdown]
# ********* Files, exceptional handling, logging and memory management Assignment Question *******

# %% [markdown]
# Ques1:What is the difference between interpreted and compiled languages?
# - Ans:Compiled languages translate the entire program into machine code before execution, while interpreted languages translate the code line by line during execution.
#
# Ques2:What is exception handling in Python?
# - Ans:Exception handling in Python is a mechanism to manage errors that occur during the execution of a program. These errors, known as exceptions, can disrupt the normal flow of the program, potentially causing it to terminate abruptly. Exception handling allows the program to gracefully handle these errors, preventing crashes and ensuring continued execution.
#
# Ques3:What is the purpose of the finally block in exception handling?
# - Ans:The purpose of the finally block in exception handling is to ensure that a specific block of code is always executed, regardless of whether an exception occurs in the preceding try block, or if any exception handling catch blocks are triggered. It's crucial for guaranteeing that critical cleanup actions, such as closing files or releasing resources, are performed consistently, even in the face of unexpected errors.
#
# Ques4:What is logging in Python?
# - Ans:Logging in Python is a built-in module that provides a flexible framework for emitting log messages from Python programs. It allows developers to track events, debug issues, and monitor the health of their applications. Logging is essential for understanding the flow of execution, identifying errors, and gaining insights into the behavior of software during runtime.
#
# Ques5:What is the significance of the __del__ method in Python?
# - Ans:The __del__ method in Python, also known as a destructor, defines actions to be performed when an object is garbage collected. It is called automatically when an object's reference count reaches zero, meaning it's no longer in use. The primary significance of __del__ lies in resource management, specifically in releasing external resources held by an object, such as closing files or network connections.
#
# Ques6:What is the difference between import and from ... import in Python?
# - Ans:The key difference between import and from ... import lies in how they make modules and their contents accessible within a program.
#
# Ques7:How can you handle multiple exceptions in Python?
# - Ans:handling multiple exceptions is crucial for writing robust and error-resistant code. When your code encounters an error, it raises an exception, which can be caught and handled using the try and except blocks. There are several techniques to catch multiple exceptions effectively.
#
# Ques8:What is the purpose of the with statement when handling files in Python?
# Ans:The with statement in Python provides a clean and reliable way to manage resources, particularly files. It ensures that files are properly opened and closed, even if errors occur during processing. This automatic resource management prevents issues like data corruption or resource leaks.
#
# Ques9:What is the difference between multithreading and multiprocessing?
# - Ans:Multithreading and multiprocessing are both techniques to run multiple tasks concurrently, but they differ in how they achieve this. Multithreading creates multiple threads within a single process, allowing for concurrent execution within that process, while multiprocessing creates multiple processes, each with its own resources, enabling parallel execution across multiple processors.
#
# Ques10:What are the advantages of using logging in a program?
# - Ans:Logging offers significant advantages in software development, including improved debugging, easier troubleshooting, enhanced system observability, and better communication between developers and administrators. It provides a record of events, helping identify issues, understand system behavior, and optimize performance.
#
# Ques11:What is memory management in Python?
# - Ans:Memory management in Python involves the allocation and deallocation of memory resources for objects. Python utilizes a private heap to store objects and data structures, and the Python memory manager oversees this heap. This process is largely automatic, relieving the programmer from manual memory management tasks common in languages like C or C++
#
# Ques12:What are the basic steps involved in exception handling in Python?
# - Ans: Exception handling in Python is a mechanism to handle runtime errors, ensuring that the program can continue its execution or terminate gracefully. Exceptions are events that disrupt the normal flow of a program, and they can be caused by various reasons such as invalid input, file not found, division by zero, etc.
#
# Ques13:Why is memory management important in Python?
# - Ans:Memory management is important in Python to ensure efficient use of system resources, prevent memory leaks, and maintain program stability. Python automates memory management through techniques like reference counting and garbage collection, which handle the allocation and deallocation of memory. Efficient memory management leads to faster processing, less resource consumption, and prevents issues like program crashes or slowdowns due to excessive memory usage. While Python handles memory management automatically, understanding its mechanisms is crucial for writing optimized and reliable code.
#
# Ques14:What is the role of try and except in exception handling?
# - Ans:In exception handling, the try and except blocks work together to gracefully manage errors that might occur during code execution. The try block contains the code that might potentially raise an exception, while the except block contains the code that handles that specific type of exception.
#
# Ques15:How does Python's garbage collection system work?
# - Ans:Python uses a hybrid approach for garbage collection: reference counting and generational garbage collection. Reference counting is the primary method, where each object has a reference count indicating how many other objects are referencing it. When an object's reference count reaches zero, it's deallocated. However, to handle circular references (where objects reference each other), Python also employs a generational garbage collector. This collector uses a mark-and-sweep algorithm to identify and reclaim memory occupied by unreachable objects, even in the presence of cycles.
#
# Ques16:What is the purpose of the else block in exception handling?
# - Ans:The else block in exception handling, often used in try...except...else structures, executes only when no exceptions are raised within the try block. It provides a way to execute code that's intended to run when the try block executes successfully, effectively separating normal execution from exception handling.
#
# Ques17:What are the common logging levels in Python?
# - Ans:Python's logging module provides a standard way to incorporate logging into applications. It defines six logging levels, each representing the severity of an event. These levels, in increasing order of severity, are:
# NOTSET (0): The default level. When a logger or handler is set to NOTSET, it processes all events.
# DEBUG (10): Detailed information, typically used for diagnosing problems.
# INFO (20): Confirmation that things are working as expected.
# WARNING (30): An indication that something unexpected happened or might happen in the near future. The software is still working as expected.
# ERROR (40): A more serious problem. A function has not been able to perform a certain task.
# CRITICAL (50): A severe error, indicating that the program itself may be unable to continue running
#
# Ques18:What is the difference between os.fork() and multiprocess?
# - Ans:One big issue is that the fork system call does not exist on Windows. Therefore, when running a Windows OS you cannot use this method. multiprocessing is a higher-level interface to execute a part of the currently running program. Therefore, it - as forking does - creates a copy of your process current state. That is to say, it takes care of the forking of your program for you.
#
# Ques19:What is the importance of closing a file in Python?
# - Ans:Closing a file in Python is an essential step to ensure that all data is properly saved and system resources are released. When you open a file using the open() function, a file object is created. This file object provides methods for reading, writing, and manipulating the file content. However, it is crucial to close the file after performing the necessary operations to avoid potential issues like data corruption and resource leaks.
#
# Ques20:What is the difference between file.read() and file.readline() in Python?
# - Ans:file.read() and file.readline() are both methods used to read data from a file object in Python, but they differ in how much data they read at a time:
# file.read(size): Reads at most size number of characters from the file and returns them as a single string. If size is omitted or negative, it reads the entire file content into a single string.
# file.readline(size): Reads at most size number of characters from the current line, including the newline character \n, and returns the line as a string. If size is omitted or negative, it reads the entire line. If the end of the file is reached, it returns an empty string.
#
# Ques21:What is the logging module in Python used for?
# - Ans:The logging module in Python is used for recording events and debugging issues during application execution. It provides a flexible system for logging messages, including errors, warnings, and informational messages, to various output destinations like files or the console.
#
# Ques22:What is the os module in Python used for in file handling?
# - Ans:Python has a built-in os module with methods for interacting with the operating system, like creating files and directories, management of files and directories, input, output, environment variables, process management, etc.
#
# Ques23:What are the challenges associated with memory management in Python?
# - Ans: Python's automatic memory management, while simplifying development, presents several challenges:
#
# Garbage Collection Overhead
# Memory Leaks
# Memory Fragmentation
# Difficulty in Predicting Memory Usage
# Limited Control
# Memory Bloat
# Reference Counting Overhead
# Space Overhead
#
# Ques24:How do you raise an exception manually in Python?
# - Ans:To raise an exception manually in Python, the raise keyword is used, followed by the exception class or an instance of an exception class. It allows for explicitly triggering an exception at a specific point in the code.
#
# Ques25:Why is it important to use multithreading in certain applications?
# - Ans:Multithreading is important in applications that benefit from concurrent execution of tasks, improved responsiveness, and efficient resource utilization. By breaking down a program into smaller, independent threads, applications can perform multiple operations simultaneously, leading to faster execution, smoother user interfaces, and better utilization of CPU cores.

# %% [markdown]
#                 ******** Practical Questions **********

# %%
#Ques1: How can you open a file for writing in Python and write a string to it?
file_path = "my_file.txt"

with open(file_path, 'w') as file:
    file.write("This is the testing1.\n")
    file.write("This is the testing2.\n")
    file.write("This is the testing3.\n")

# %%
#Ques2: Write a Python program to read the contents of a file and print each line.
file_path = "my_file.txt"
with open(file_path, 'r') as file:
            for line in file:
                print(line, end="")
# Out:
# This is the testing1.
# This is the testing2.
# This is the testing3.

# %%
#Ques3: How would you handle a case where the file doesn't exist while trying to open it for reading?
file_path = "my_file1.txt"
try:
    with open(file_path, 'r') as file:
        contents = file.read()
except FileNotFoundError:
    print(f"Error: File '{file_path}' not found.")
# Out:
# Error: File 'my_file1.txt' not found.

# %%
#Ques4: Write a Python script that reads from one file and writes its content to another file
import shutil
s_path = "my_file.txt"
d_path = "Copy_file.txt"
try:
  with open(s_path, 'r') as source, open(d_path, 'w') as destination:
    shutil.copyfileobj(source, destination)
    print(f"File '{s_path}' copied to '{d_path}' successfully.")
except FileNotFoundError:
  print(f"Error: Source file '{s_path}' not found.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# File 'my_file.txt' copied to 'Copy_file.txt' successfully.

# %%
#Ques5: How would you catch and handle division by zero error in Python?
try:
    numerator = 10
    denominator = 2
    result = numerator / denominator
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
else:
    print("Result:", result)  # Executes if no exception occurs
finally:
    print("Execution complete.")  # Always executes
# Out:
# Result: 5.0
# Execution complete.

# %%
#Ques6:Write a Python program that logs an error message to a log file when a division by zero exception occurs.
import logging

logging.basicConfig(filename='error_log.txt', level=logging.ERROR)

# %%
#Ques7: How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
import logging
logging.debug('This message is for debugging purposes.')
logging.info('Informational message.')
logging.warning('Something might be wrong.')
logging.error('An error occurred.')
logging.critical('A critical error occurred; the program might terminate.')
# Out:
# WARNING:root:Something might be wrong.
# ERROR:root:An error occurred.
# CRITICAL:root:A critical error occurred; the program might terminate.

# %%
#Ques8:Write a program to handle a file opening error using exception handling?
try:
  file_path = "my_file.txt"
  with open(file_path, 'r') as file:
        contents = file.read()
        print(contents)
except FileNotFoundError:
    print(f"Error: File '{file_path}' not found.")
# Out:
# This is the testing1.
# This is the testing2.
# This is the testing3.

# %%
#Ques9: How can you read a file line by line and store its content in a list in Python?
file_path = "my_file.txt"
try:
  with open(file_path, 'r') as file:
    lines = file.readlines()
    #lines = [line.strip() for line in lines]
    print(lines)
except FileNotFoundError:
    print(f"Error: File '{file_path}' not found.")
# Out:
# ['This is the testing1.\n', 'This is the testing2.\n', 'This is the testing3.\n', 'Line 1\n', 'Line 2\n', 'Line 3\n']

# %%
#Ques10:How can you append data to an existing file in Python?
lines_to_append = ['Line 1\n', 'Line 2\n', 'Line 3\n']
with open('my_file.txt', 'a') as file:
    file.writelines(lines_to_append)

# %%
#Ques11: Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.
my_dict = {"a": 1, "b": 2, "c": 3}
try:
    value = my_dict["d"]
    print(f"The value is: {value}")
except KeyError:
    print("Error: Key 'd' not found in the dictionary.")
# Out:
# Error: Key 'd' not found in the dictionary.

# %%
#Ques12: Write a program that demonstrates using multiple except blocks to handle different types of exceptions?
try:
    numerator = int(input("Enter the numerator: "))
    denominator = int(input("Enter the denominator: "))
    result = numerator / denominator
    print("Result of division:", result)

    my_list = [1, 2, 3]
    print("Element at index 4:", my_list[4])

except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except ValueError:
    print("Error: Invalid input. Please enter integers only.")
except IndexError:
    print("Error: List index out of range.")
except Exception as e:  # Catches any other exception
    print(f"An unexpected error occurred: {e}")  # Prints the exception object
else: # This block is only executed if the code inside the try block does not raise exceptions
    print("No exceptions occurred during the try block execution")
finally:
    print("This finally block always executes, cleaning up or finalizing operations if necessary.")
# Out:
# Enter the numerator: 20
# Enter the denominator: 100
# Result of division: 0.2
# Error: List index out of range.
# This finally block always executes, cleaning up or finalizing operations if necessary.

# %%
#Ques13: How would you check if a file exists before attempting to read it in Python?
import os
from pathlib import Path
file_path = "my_file.txt"
if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
    print("File content:", content)
else:
    print("File does not exist.")
# Out:
# File content: This is the testing1.
# This is the testing2.
# This is the testing3.
# Line 1
# Line 2
# Line 3

# %%
#Ques14:Write a program that uses the logging module to log both informational and error messages?
import logging
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='app.log',
    filemode='w'
)

logging.info('Application started')
logging.info('Loading configuration file...')

try:
    result = 10 / 0
except ZeroDivisionError as e:
    logging.error(f'An error occurred: {e}')
logging.info('Configuration file loaded successfully')
logging.info('Application finished')
# Out:
# ERROR:root:An error occurred: division by zero

# %%
#Ques15:Write a Python program that prints the content of a file and handles the case when the file is empty?
file_path = "my_file.txt"
try:
  with open(file_path, 'r') as file:
        content = file.read()
        if content!="":
          print("File content:", content)
        else:
            print("The file is empty.")
except FileNotFoundError:
    print(f"Error: File '{file_path}' not found.")
# Out:
# File content: This is the testing1.
# This is the testing2.
# This is the testing3.
# Line 1
# Line 2
# Line 3

# %%
#Ques16:Demonstrate how to use memory profiling to check the memory usage of a small program.
import profile
def my_function():
    my_list = list(range(10000))
    print(len(my_list))
my_function()
# Out:
# 10000

# %%
#Ques17:Write a Python program to create and write a list of numbers to a file, one number per line.
numbers = [1, 2, 3, 4, 5]
with open('numbers.txt', 'w') as file:
    for num in numbers:
        file.write(str(num) + '\n')

# %%
#Ques18:How would you implement a basic logging setup that logs to a file with rotation after 1MB?
import logging
from logging.handlers import RotatingFileHandler

def setup_rotating_log(log_file_path, max_bytes=1048576, backup_count=5):
    """Set up a rotating log file.

    Args:
        log_file_path: The path to the log file.
        max_bytes: The maximum size of the log file in bytes before rotating.
                     Defaults to 1MB (1048576 bytes).
        backup_count: The number of backup log files to keep.
    """
    logger = logging.getLogger(__name__)  # Using __name__ is good practice for module-level logging
    logger.setLevel(logging.DEBUG)  # Set logging level (DEBUG, INFO, WARNING, ERROR, CRITICAL)

    # Create a rotating file handler:
    handler = RotatingFileHandler(log_file_path, maxBytes=max_bytes, backupCount=backup_count)

    # Create and set a formatter (optional, but recommended):
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')  # Customize format as needed
    handler.setFormatter(formatter)

    # Add the handler to the logger:
    logger.addHandler(handler)
    return logger

# Example Usage:
log_file = "my_rotating_log.log"
logger = setup_rotating_log(log_file)

logger.debug("This is a debug message.")
logger.info("This is an info message.")
logger.warning("This is a warning message.")
logger.error("This is an error message.")
logger.critical("This is a critical message.")

for i in range(2000): # Write enough log entries to trigger the rotation a few times:
    logger.debug(f"This is log entry number {i+1}.")
# Out:
# DEBUG:__main__:This is a debug message.
# INFO:__main__:This is an info message.
# WARNING:__main__:This is a warning message.
# ERROR:__main__:This is an error message.
# CRITICAL:__main__:This is a critical message.
# DEBUG:__main__:This is log entry number 1.
# DEBUG:__main__:This is log entry number 2.
# DEBUG:__main__:This is log entry number 3.
# DEBUG:__main__:This is log entry number 4.
# DEBUG:__main__:This is log entry number 5.
# DEBUG:__main__:This is log entry number 6.
# DEBUG:__main__:This is log entry number 7.
# DEBUG:__main__:This is log entry number 8.
# DEBUG:__main__:This is log entry number 9.
# DEBUG:__main__:This is log entry number 10.
# DEBUG:__main__:This is log entry number 11.
# DEBUG:__main__:This is log entry number 12.
# DEBUG:__main__:This is log entry number 13.
# DEBUG:__main__:This is log entry number 14.
# DEBUG:__main__:This is log entry number 15.
# DEBUG:__main__:This is log entry number 16.
# DEBUG:__main__:This is log entry number 17.
# DEBUG:__main__:This is log entry number 18.
# DEBUG:__main__:This is log entry number 19.
# DEBUG:__main__:This is log entry number 20.
# DEBUG:__main__:This is log entry number 21.
# DEBUG:__main__:This is log entry number 22.
# DEBUG:__main__:This is log entry number 23.
# DEBUG:__main__:This is log entry number 24.
# DEBUG:__main__:This is log entry number 25.
# DEBUG:__main__:This is log entry number 26.
# DEBUG:__main__:This is log entry number 27.
# DEBUG:__main__:This is log entry number 28.
# DEBUG:__main__:This is log entry number 29.
# DEBUG:__main__:This is log entry number 30.
# DEBUG:__main__:This is log entry number 31.
# DEBUG:__main__:This is log entry number 32.
# DEBUG:__main__:This is log entry number 33.
# DEBUG:__main__:This is log entry number 34.
# DEBUG:__main__:This is log entry number 35.
# DEBUG:__main__:This is log entry number 36.
# DEBUG:__main__:This is log entry number 37.
# DEBUG:__main__:This is log entry number 38.
# DEBUG:__main__:This is log entry number 39.
# DEBUG:__main__:This is log entry number 40.
# DEBUG:__main__:This is log entry number 41.
# DEBUG:__main__:This is log entry number 42.
# DEBUG:__main__:This is log entry number 43.
# DEBUG:__main__:This is log entry number 44.
# DEBUG:__main__:This is log entry number 45.
# DEBUG:__main__:This is log entry number 46.
# DEBUG:__main__:This is log entry number 47.
# DEBUG:__main__:This is log entry number 48.
# DEBUG:__main__:This is log entry number 49.
# DEBUG:__main__:This is log entry number 50.
# DEBUG:__main__:This is log entry number 51.
# DEBUG:__main__:This is log entry number 52.
# DEBUG:__main__:This is log entry number 53.
# DEBUG:__main__:This is log entry number 54.
# DEBUG:__main__:This is log entry number 55.
# DEBUG:__main__:This is log entry number 56.
# DEBUG:__main__:This is log entry number 57.
# DEBUG:__main__:This is log entry number 58.
# DEBUG:__main__:This is log entry number 59.
# DEBUG:__main__:This is log entry number 60.
# DEBUG:__main__:This is log entry number 61.
# DEBUG:__main__:This is log entry number 62.
# DEBUG:__main__:This is log entry number 63.
# DEBUG:__main__:This is log entry number 64.
# DEBUG:__main__:This is log entry number 65.
# DEBUG:__main__:This is log entry number 66.
# DEBUG:__main__:This is log entry number 67.
# DEBUG:__main__:This is log entry number 68.
# DEBUG:__main__:This is log entry number 69.
# DEBUG:__main__:This is log entry number 70.
# DEBUG:__main__:This is log entry number 71.
# DEBUG:__main__:This is log entry number 72.
# DEBUG:__main__:This is log entry number 73.
# DEBUG:__main__:This is log entry number 74.
# DEBUG:__main__:This is log entry number 75.
# DEBUG:__main__:This is log entry number 76.
# DEBUG:__main__:This is log entry number 77.
# DEBUG:__main__:This is log entry number 78.
# DEBUG:__main__:This is log entry number 79.
# DEBUG:__main__:This is log entry number 80.
# DEBUG:__main__:This is log entry number 81.
# DEBUG:__main__:This is log entry number 82.
# DEBUG:__main__:This is log entry number 83.
# DEBUG:__main__:This is log entry number 84.
# DEBUG:__main__:This is log entry number 85.
# DEBUG:__main__:This is log entry number 86.
# DEBUG:__main__:This is log entry number 87.
# DEBUG:__main__:This is log entry number 88.
# DEBUG:__main__:This is log entry number 89.
# DEBUG:__main__:This is log entry number 90.
# DEBUG:__main__:This is log entry number 91.
# DEBUG:__main__:This is log entry number 92.
# DEBUG:__main__:This is log entry number 93.
# DEBUG:__main__:This is log entry number 94.
# DEBUG:__main__:This is log entry number 95.
# DEBUG:__main__:This is log entry number 96.
# DEBUG:__main__:This is log entry number 97.
# DEBUG:__main__:This is log entry number 98.
# DEBUG:__main__:This is log entry number 99.
# DEBUG:__main__:This is log entry number 100.
# DEBUG:__main__:This is log entry number 101.
# DEBUG:__main__:This is log entry number 102.
# DEBUG:__main__:This is log entry number 103.
# DEBUG:__main__:This is log entry number 104.
# DEBUG:__main__:This is log entry number 105.
# DEBUG:__main__:This is log entry number 106.
# DEBUG:__main__:This is log entry number 107.
# DEBUG:__main__:This is log entry number 108.
# DEBUG:__main__:This is log entry number 109.
# DEBUG:__main__:This is log entry number 110.
# DEBUG:__main__:This is log entry number 111.
# DEBUG:__main__:This is log entry number 112.
# DEBUG:__main__:This is log entry number 113.
# DEBUG:__main__:This is log entry number 114.
# DEBUG:__main__:This is log entry number 115.
# DEBUG:__main__:This is log entry number 116.
# DEBUG:__main__:This is log entry number 117.
# DEBUG:__main__:This is log entry number 118.
# DEBUG:__main__:This is log entry number 119.
# DEBUG:__main__:This is log entry number 120.
# DEBUG:__main__:This is log entry number 121.
# DEBUG:__main__:This is log entry number 122.
# DEBUG:__main__:This is log entry number 123.
# DEBUG:__main__:This is log entry number 124.
# DEBUG:__main__:This is log entry number 125.
# DEBUG:__main__:This is log entry number 126.
# DEBUG:__main__:This is log entry number 127.
# DEBUG:__main__:This is log entry number 128.
# DEBUG:__main__:This is log entry number 129.
# DEBUG:__main__:This is log entry number 130.
# DEBUG:__main__:This is log entry number 131.
# DEBUG:__main__:This is log entry number 132.
# DEBUG:__main__:This is log entry number 133.
# DEBUG:__main__:This is log entry number 134.
# DEBUG:__main__:This is log entry number 135.
# DEBUG:__main__:This is log entry number 136.
# DEBUG:__main__:This is log entry number 137.
# DEBUG:__main__:This is log entry number 138.
# DEBUG:__main__:This is log entry number 139.
# DEBUG:__main__:This is log entry number 140.
# DEBUG:__main__:This is log entry number 141.
# DEBUG:__main__:This is log entry number 142.
# DEBUG:__main__:This is log entry number 143.
# DEBUG:__main__:This is log entry number 144.
# DEBUG:__main__:This is log entry number 145.
# DEBUG:__main__:This is log entry number 146.
# DEBUG:__main__:This is log entry number 147.
# DEBUG:__main__:This is log entry number 148.
# DEBUG:__main__:This is log entry number 149.
# DEBUG:__main__:This is log entry number 150.
# DEBUG:__main__:This is log entry number 151.
# DEBUG:__main__:This is log entry number 152.
# DEBUG:__main__:This is log entry number 153.
# DEBUG:__main__:This is log entry number 154.
# DEBUG:__main__:This is log entry number 155.
# DEBUG:__main__:This is log entry number 156.
# DEBUG:__main__:This is log entry number 157.
# DEBUG:__main__:This is log entry number 158.
# DEBUG:__main__:This is log entry number 159.
# DEBUG:__main__:This is log entry number 160.
# DEBUG:__main__:This is log entry number 161.
# DEBUG:__main__:This is log entry number 162.
# DEBUG:__main__:This is log entry number 163.
# DEBUG:__main__:This is log entry number 164.
# DEBUG:__main__:This is log entry number 165.
# DEBUG:__main__:This is log entry number 166.
# DEBUG:__main__:This is log entry number 167.
# DEBUG:__main__:This is log entry number 168.
# DEBUG:__main__:This is log entry number 169.
# DEBUG:__main__:This is log entry number 170.
# DEBUG:__main__:This is log entry number 171.
# DEBUG:__main__:This is log entry number 172.
# DEBUG:__main__:This is log entry number 173.
# DEBUG:__main__:This is log entry number 174.
# DEBUG:__main__:This is log entry number 175.
# DEBUG:__main__:This is log entry number 176.
# DEBUG:__main__:This is log entry number 177.
# DEBUG:__main__:This is log entry number 178.
# DEBUG:__main__:This is log entry number 179.
# DEBUG:__main__:This is log entry number 180.
# DEBUG:__main__:This is log entry number 181.
# DEBUG:__main__:This is log entry number 182.
# DEBUG:__main__:This is log entry number 183.
# DEBUG:__main__:This is log entry number 184.
# DEBUG:__main__:This is log entry number 185.
# DEBUG:__main__:This is log entry number 186.
# DEBUG:__main__:This is log entry number 187.
# DEBUG:__main__:This is log entry number 188.
# DEBUG:__main__:This is log entry number 189.
# DEBUG:__main__:This is log entry number 190.
# DEBUG:__main__:This is log entry number 191.
# DEBUG:__main__:This is log entry number 192.
# DEBUG:__main__:This is log entry number 193.
# DEBUG:__main__:This is log entry number 194.
# DEBUG:__main__:This is log entry number 195.
# DEBUG:__main__:This is log entry number 196.
# DEBUG:__main__:This is log entry number 197.
# DEBUG:__main__:This is log entry number 198.
# DEBUG:__main__:This is log entry number 199.
# DEBUG:__main__:This is log entry number 200.
# DEBUG:__main__:This is log entry number 201.
# DEBUG:__main__:This is log entry number 202.
# DEBUG:__main__:This is log entry number 203.
# DEBUG:__main__:This is log entry number 204.
# DEBUG:__main__:This is log entry number 205.
# DEBUG:__main__:This is log entry number 206.
# DEBUG:__main__:This is log entry number 207.
# DEBUG:__main__:This is log entry number 208.
# DEBUG:__main__:This is log entry number 209.
# DEBUG:__main__:This is log entry number 210.
# DEBUG:__main__:This is log entry number 211.
# DEBUG:__main__:This is log entry number 212.
# DEBUG:__main__:This is log entry number 213.
# DEBUG:__main__:This is log entry number 214.
# DEBUG:__main__:This is log entry number 215.
# DEBUG:__main__:This is log entry number 216.
# DEBUG:__main__:This is log entry number 217.
# DEBUG:__main__:This is log entry number 218.
# DEBUG:__main__:This is log entry number 219.
# DEBUG:__main__:This is log entry number 220.
# DEBUG:__main__:This is log entry number 221.
# DEBUG:__main__:This is log entry number 222.
# DEBUG:__main__:This is log entry number 223.
# DEBUG:__main__:This is log entry number 224.
# DEBUG:__main__:This is log entry number 225.
# DEBUG:__main__:This is log entry number 226.
# DEBUG:__main__:This is log entry number 227.
# DEBUG:__main__:This is log entry number 228.
# DEBUG:__main__:This is log entry number 229.
# DEBUG:__main__:This is log entry number 230.
# DEBUG:__main__:This is log entry number 231.
# DEBUG:__main__:This is log entry number 232.
# DEBUG:__main__:This is log entry number 233.
# DEBUG:__main__:This is log entry number 234.
# DEBUG:__main__:This is log entry number 235.
# DEBUG:__main__:This is log entry number 236.
# DEBUG:__main__:This is log entry number 237.
# DEBUG:__main__:This is log entry number 238.
# DEBUG:__main__:This is log entry number 239.
# DEBUG:__main__:This is log entry number 240.
# DEBUG:__main__:This is log entry number 241.
# DEBUG:__main__:This is log entry number 242.
# DEBUG:__main__:This is log entry number 243.
# DEBUG:__main__:This is log entry number 244.
# DEBUG:__main__:This is log entry number 245.
# DEBUG:__main__:This is log entry number 246.
# DEBUG:__main__:This is log entry number 247.
# DEBUG:__main__:This is log entry number 248.
# DEBUG:__main__:This is log entry number 249.
# DEBUG:__main__:This is log entry number 250.
# DEBUG:__main__:This is log entry number 251.
# DEBUG:__main__:This is log entry number 252.
# DEBUG:__main__:This is log entry number 253.
# DEBUG:__main__:This is log entry number 254.
# DEBUG:__main__:This is log entry number 255.
# DEBUG:__main__:This is log entry number 256.
# DEBUG:__main__:This is log entry number 257.
# DEBUG:__main__:This is log entry number 258.
# DEBUG:__main__:This is log entry number 259.
# DEBUG:__main__:This is log entry number 260.
# DEBUG:__main__:This is log entry number 261.
# DEBUG:__main__:This is log entry number 262.
# DEBUG:__main__:This is log entry number 263.
# DEBUG:__main__:This is log entry number 264.
# DEBUG:__main__:This is log entry number 265.
# DEBUG:__main__:This is log entry number 266.
# DEBUG:__main__:This is log entry number 267.
# DEBUG:__main__:This is log entry number 268.
# DEBUG:__main__:This is log entry number 269.
# DEBUG:__main__:This is log entry number 270.
# DEBUG:__main__:This is log entry number 271.
# DEBUG:__main__:This is log entry number 272.
# DEBUG:__main__:This is log entry number 273.
# DEBUG:__main__:This is log entry number 274.
# DEBUG:__main__:This is log entry number 275.
# DEBUG:__main__:This is log entry number 276.
# DEBUG:__main__:This is log entry number 277.
# DEBUG:__main__:This is log entry number 278.
# DEBUG:__main__:This is log entry number 279.
# DEBUG:__main__:This is log entry number 280.
# DEBUG:__main__:This is log entry number 281.
# DEBUG:__main__:This is log entry number 282.
# DEBUG:__main__:This is log entry number 283.
# DEBUG:__main__:This is log entry number 284.
# DEBUG:__main__:This is log entry number 285.
# DEBUG:__main__:This is log entry number 286.
# DEBUG:__main__:This is log entry number 287.
# DEBUG:__main__:This is log entry number 288.
# DEBUG:__main__:This is log entry number 289.
# DEBUG:__main__:This is log entry number 290.
# DEBUG:__main__:This is log entry number 291.
# DEBUG:__main__:This is log entry number 292.
# DEBUG:__main__:This is log entry number 293.
# DEBUG:__main__:This is log entry number 294.
# DEBUG:__main__:This is log entry number 295.
# DEBUG:__main__:This is log entry number 296.
# DEBUG:__main__:This is log entry number 297.
# DEBUG:__main__:This is log entry number 298.
# DEBUG:__main__:This is log entry number 299.
# DEBUG:__main__:This is log entry number 300.
# DEBUG:__main__:This is log entry number 301.
# DEBUG:__main__:This is log entry number 302.
# DEBUG:__main__:This is log entry number 303.
# DEBUG:__main__:This is log entry number 304.
# DEBUG:__main__:This is log entry number 305.
# DEBUG:__main__:This is log entry number 306.
# DEBUG:__main__:This is log entry number 307.
# DEBUG:__main__:This is log entry number 308.
# DEBUG:__main__:This is log entry number 309.
# DEBUG:__main__:This is log entry number 310.
# DEBUG:__main__:This is log entry number 311.
# DEBUG:__main__:This is log entry number 312.
# DEBUG:__main__:This is log entry number 313.
# DEBUG:__main__:This is log entry number 314.
# DEBUG:__main__:This is log entry number 315.
# DEBUG:__main__:This is log entry number 316.
# DEBUG:__main__:This is log entry number 317.
# DEBUG:__main__:This is log entry number 318.
# DEBUG:__main__:This is log entry number 319.
# DEBUG:__main__:This is log entry number 320.
# DEBUG:__main__:This is log entry number 321.
# DEBUG:__main__:This is log entry number 322.
# DEBUG:__main__:This is log entry number 323.
# DEBUG:__main__:This is log entry number 324.
# DEBUG:__main__:This is log entry number 325.
# DEBUG:__main__:This is log entry number 326.
# DEBUG:__main__:This is log entry number 327.
# DEBUG:__main__:This is log entry number 328.
# DEBUG:__main__:This is log entry number 329.
# DEBUG:__main__:This is log entry number 330.
# DEBUG:__main__:This is log entry number 331.
# DEBUG:__main__:This is log entry number 332.
# DEBUG:__main__:This is log entry number 333.
# DEBUG:__main__:This is log entry number 334.
# DEBUG:__main__:This is log entry number 335.
# DEBUG:__main__:This is log entry number 336.
# DEBUG:__main__:This is log entry number 337.
# DEBUG:__main__:This is log entry number 338.
# DEBUG:__main__:This is log entry number 339.
# DEBUG:__main__:This is log entry number 340.
# DEBUG:__main__:This is log entry number 341.
# DEBUG:__main__:This is log entry number 342.
# DEBUG:__main__:This is log entry number 343.
# DEBUG:__main__:This is log entry number 344.
# DEBUG:__main__:This is log entry number 345.
# DEBUG:__main__:This is log entry number 346.
# DEBUG:__main__:This is log entry number 347.
# DEBUG:__main__:This is log entry number 348.
# DEBUG:__main__:This is log entry number 349.
# DEBUG:__main__:This is log entry number 350.
# DEBUG:__main__:This is log entry number 351.
# DEBUG:__main__:This is log entry number 352.
# DEBUG:__main__:This is log entry number 353.
# DEBUG:__main__:This is log entry number 354.
# DEBUG:__main__:This is log entry number 355.
# DEBUG:__main__:This is log entry number 356.
# DEBUG:__main__:This is log entry number 357.
# DEBUG:__main__:This is log entry number 358.
# DEBUG:__main__:This is log entry number 359.
# DEBUG:__main__:This is log entry number 360.
# DEBUG:__main__:This is log entry number 361.
# DEBUG:__main__:This is log entry number 362.
# DEBUG:__main__:This is log entry number 363.
# DEBUG:__main__:This is log entry number 364.
# DEBUG:__main__:This is log entry number 365.
# DEBUG:__main__:This is log entry number 366.
# DEBUG:__main__:This is log entry number 367.
# DEBUG:__main__:This is log entry number 368.
# DEBUG:__main__:This is log entry number 369.
# DEBUG:__main__:This is log entry number 370.
# DEBUG:__main__:This is log entry number 371.
# DEBUG:__main__:This is log entry number 372.
# DEBUG:__main__:This is log entry number 373.
# DEBUG:__main__:This is log entry number 374.
# DEBUG:__main__:This is log entry number 375.
# DEBUG:__main__:This is log entry number 376.
# DEBUG:__main__:This is log entry number 377.
# DEBUG:__main__:This is log entry number 378.
# DEBUG:__main__:This is log entry number 379.
# DEBUG:__main__:This is log entry number 380.
# DEBUG:__main__:This is log entry number 381.
# DEBUG:__main__:This is log entry number 382.
# DEBUG:__main__:This is log entry number 383.
# DEBUG:__main__:This is log entry number 384.
# DEBUG:__main__:This is log entry number 385.
# DEBUG:__main__:This is log entry number 386.
# DEBUG:__main__:This is log entry number 387.
# DEBUG:__main__:This is log entry number 388.
# DEBUG:__main__:This is log entry number 389.
# DEBUG:__main__:This is log entry number 390.
# DEBUG:__main__:This is log entry number 391.
# DEBUG:__main__:This is log entry number 392.
# DEBUG:__main__:This is log entry number 393.
# DEBUG:__main__:This is log entry number 394.
# DEBUG:__main__:This is log entry number 395.
# DEBUG:__main__:This is log entry number 396.
# DEBUG:__main__:This is log entry number 397.
# DEBUG:__main__:This is log entry number 398.
# DEBUG:__main__:This is log entry number 399.
# DEBUG:__main__:This is log entry number 400.
# DEBUG:__main__:This is log entry number 401.
# DEBUG:__main__:This is log entry number 402.
# DEBUG:__main__:This is log entry number 403.
# DEBUG:__main__:This is log entry number 404.
# DEBUG:__main__:This is log entry number 405.
# DEBUG:__main__:This is log entry number 406.
# DEBUG:__main__:This is log entry number 407.
# DEBUG:__main__:This is log entry number 408.
# DEBUG:__main__:This is log entry number 409.
# DEBUG:__main__:This is log entry number 410.
# DEBUG:__main__:This is log entry number 411.
# DEBUG:__main__:This is log entry number 412.
# DEBUG:__main__:This is log entry number 413.
# DEBUG:__main__:This is log entry number 414.
# DEBUG:__main__:This is log entry number 415.
# DEBUG:__main__:This is log entry number 416.
# DEBUG:__main__:This is log entry number 417.
# DEBUG:__main__:This is log entry number 418.
# DEBUG:__main__:This is log entry number 419.
# DEBUG:__main__:This is log entry number 420.
# DEBUG:__main__:This is log entry number 421.
# DEBUG:__main__:This is log entry number 422.
# DEBUG:__main__:This is log entry number 423.
# DEBUG:__main__:This is log entry number 424.
# DEBUG:__main__:This is log entry number 425.
# DEBUG:__main__:This is log entry number 426.
# DEBUG:__main__:This is log entry number 427.
# DEBUG:__main__:This is log entry number 428.
# DEBUG:__main__:This is log entry number 429.
# DEBUG:__main__:This is log entry number 430.
# DEBUG:__main__:This is log entry number 431.
# DEBUG:__main__:This is log entry number 432.
# DEBUG:__main__:This is log entry number 433.
# DEBUG:__main__:This is log entry number 434.
# DEBUG:__main__:This is log entry number 435.
# DEBUG:__main__:This is log entry number 436.
# DEBUG:__main__:This is log entry number 437.
# DEBUG:__main__:This is log entry number 438.
# DEBUG:__main__:This is log entry number 439.
# DEBUG:__main__:This is log entry number 440.
# DEBUG:__main__:This is log entry number 441.
# DEBUG:__main__:This is log entry number 442.
# DEBUG:__main__:This is log entry number 443.
# DEBUG:__main__:This is log entry number 444.
# DEBUG:__main__:This is log entry number 445.
# DEBUG:__main__:This is log entry number 446.
# DEBUG:__main__:This is log entry number 447.
# DEBUG:__main__:This is log entry number 448.
# DEBUG:__main__:This is log entry number 449.
# DEBUG:__main__:This is log entry number 450.
# DEBUG:__main__:This is log entry number 451.
# DEBUG:__main__:This is log entry number 452.
# DEBUG:__main__:This is log entry number 453.
# DEBUG:__main__:This is log entry number 454.
# DEBUG:__main__:This is log entry number 455.
# DEBUG:__main__:This is log entry number 456.
# DEBUG:__main__:This is log entry number 457.
# DEBUG:__main__:This is log entry number 458.
# DEBUG:__main__:This is log entry number 459.
# DEBUG:__main__:This is log entry number 460.
# DEBUG:__main__:This is log entry number 461.
# DEBUG:__main__:This is log entry number 462.
# DEBUG:__main__:This is log entry number 463.
# DEBUG:__main__:This is log entry number 464.
# DEBUG:__main__:This is log entry number 465.
# DEBUG:__main__:This is log entry number 466.
# DEBUG:__main__:This is log entry number 467.
# DEBUG:__main__:This is log entry number 468.
# DEBUG:__main__:This is log entry number 469.
# DEBUG:__main__:This is log entry number 470.
# DEBUG:__main__:This is log entry number 471.
# DEBUG:__main__:This is log entry number 472.
# DEBUG:__main__:This is log entry number 473.
# DEBUG:__main__:This is log entry number 474.
# DEBUG:__main__:This is log entry number 475.
# DEBUG:__main__:This is log entry number 476.
# DEBUG:__main__:This is log entry number 477.
# DEBUG:__main__:This is log entry number 478.
# DEBUG:__main__:This is log entry number 479.
# DEBUG:__main__:This is log entry number 480.
# DEBUG:__main__:This is log entry number 481.
# DEBUG:__main__:This is log entry number 482.
# DEBUG:__main__:This is log entry number 483.
# DEBUG:__main__:This is log entry number 484.
# DEBUG:__main__:This is log entry number 485.
# DEBUG:__main__:This is log entry number 486.
# DEBUG:__main__:This is log entry number 487.
# DEBUG:__main__:This is log entry number 488.
# DEBUG:__main__:This is log entry number 489.
# DEBUG:__main__:This is log entry number 490.
# DEBUG:__main__:This is log entry number 491.
# DEBUG:__main__:This is log entry number 492.
# DEBUG:__main__:This is log entry number 493.
# DEBUG:__main__:This is log entry number 494.
# DEBUG:__main__:This is log entry number 495.
# DEBUG:__main__:This is log entry number 496.
# DEBUG:__main__:This is log entry number 497.
# DEBUG:__main__:This is log entry number 498.
# DEBUG:__main__:This is log entry number 499.
# DEBUG:__main__:This is log entry number 500.
# DEBUG:__main__:This is log entry number 501.
# DEBUG:__main__:This is log entry number 502.
# DEBUG:__main__:This is log entry number 503.
# DEBUG:__main__:This is log entry number 504.
# DEBUG:__main__:This is log entry number 505.
# DEBUG:__main__:This is log entry number 506.
# DEBUG:__main__:This is log entry number 507.
# DEBUG:__main__:This is log entry number 508.
# DEBUG:__main__:This is log entry number 509.
# DEBUG:__main__:This is log entry number 510.
# DEBUG:__main__:This is log entry number 511.
# DEBUG:__main__:This is log entry number 512.
# DEBUG:__main__:This is log entry number 513.
# DEBUG:__main__:This is log entry number 514.
# DEBUG:__main__:This is log entry number 515.
# DEBUG:__main__:This is log entry number 516.
# DEBUG:__main__:This is log entry number 517.
# DEBUG:__main__:This is log entry number 518.
# DEBUG:__main__:This is log entry number 519.
# DEBUG:__main__:This is log entry number 520.
# DEBUG:__main__:This is log entry number 521.
# DEBUG:__main__:This is log entry number 522.
# DEBUG:__main__:This is log entry number 523.
# DEBUG:__main__:This is log entry number 524.
# DEBUG:__main__:This is log entry number 525.
# DEBUG:__main__:This is log entry number 526.
# DEBUG:__main__:This is log entry number 527.
# DEBUG:__main__:This is log entry number 528.
# DEBUG:__main__:This is log entry number 529.
# DEBUG:__main__:This is log entry number 530.
# DEBUG:__main__:This is log entry number 531.
# DEBUG:__main__:This is log entry number 532.
# DEBUG:__main__:This is log entry number 533.
# DEBUG:__main__:This is log entry number 534.
# DEBUG:__main__:This is log entry number 535.
# DEBUG:__main__:This is log entry number 536.
# DEBUG:__main__:This is log entry number 537.
# DEBUG:__main__:This is log entry number 538.
# DEBUG:__main__:This is log entry number 539.
# DEBUG:__main__:This is log entry number 540.
# DEBUG:__main__:This is log entry number 541.
# DEBUG:__main__:This is log entry number 542.
# DEBUG:__main__:This is log entry number 543.
# DEBUG:__main__:This is log entry number 544.
# DEBUG:__main__:This is log entry number 545.
# DEBUG:__main__:This is log entry number 546.
# DEBUG:__main__:This is log entry number 547.
# DEBUG:__main__:This is log entry number 548.
# DEBUG:__main__:This is log entry number 549.
# DEBUG:__main__:This is log entry number 550.
# DEBUG:__main__:This is log entry number 551.
# DEBUG:__main__:This is log entry number 552.
# DEBUG:__main__:This is log entry number 553.
# DEBUG:__main__:This is log entry number 554.
# DEBUG:__main__:This is log entry number 555.
# DEBUG:__main__:This is log entry number 556.
# DEBUG:__main__:This is log entry number 557.
# DEBUG:__main__:This is log entry number 558.
# DEBUG:__main__:This is log entry number 559.
# DEBUG:__main__:This is log entry number 560.
# DEBUG:__main__:This is log entry number 561.
# DEBUG:__main__:This is log entry number 562.
# DEBUG:__main__:This is log entry number 563.
# DEBUG:__main__:This is log entry number 564.
# DEBUG:__main__:This is log entry number 565.
# DEBUG:__main__:This is log entry number 566.
# DEBUG:__main__:This is log entry number 567.
# DEBUG:__main__:This is log entry number 568.
# DEBUG:__main__:This is log entry number 569.
# DEBUG:__main__:This is log entry number 570.
# DEBUG:__main__:This is log entry number 571.
# DEBUG:__main__:This is log entry number 572.
# DEBUG:__main__:This is log entry number 573.
# DEBUG:__main__:This is log entry number 574.
# DEBUG:__main__:This is log entry number 575.
# DEBUG:__main__:This is log entry number 576.
# DEBUG:__main__:This is log entry number 577.
# DEBUG:__main__:This is log entry number 578.
# DEBUG:__main__:This is log entry number 579.
# DEBUG:__main__:This is log entry number 580.
# DEBUG:__main__:This is log entry number 581.
# DEBUG:__main__:This is log entry number 582.
# DEBUG:__main__:This is log entry number 583.
# DEBUG:__main__:This is log entry number 584.
# DEBUG:__main__:This is log entry number 585.
# DEBUG:__main__:This is log entry number 586.
# DEBUG:__main__:This is log entry number 587.
# DEBUG:__main__:This is log entry number 588.
# DEBUG:__main__:This is log entry number 589.
# DEBUG:__main__:This is log entry number 590.
# DEBUG:__main__:This is log entry number 591.
# DEBUG:__main__:This is log entry number 592.
# DEBUG:__main__:This is log entry number 593.
# DEBUG:__main__:This is log entry number 594.
# DEBUG:__main__:This is log entry number 595.
# DEBUG:__main__:This is log entry number 596.
# DEBUG:__main__:This is log entry number 597.
# DEBUG:__main__:This is log entry number 598.
# DEBUG:__main__:This is log entry number 599.
# DEBUG:__main__:This is log entry number 600.
# DEBUG:__main__:This is log entry number 601.
# DEBUG:__main__:This is log entry number 602.
# DEBUG:__main__:This is log entry number 603.
# DEBUG:__main__:This is log entry number 604.
# DEBUG:__main__:This is log entry number 605.
# DEBUG:__main__:This is log entry number 606.
# DEBUG:__main__:This is log entry number 607.
# DEBUG:__main__:This is log entry number 608.
# DEBUG:__main__:This is log entry number 609.
# DEBUG:__main__:This is log entry number 610.
# DEBUG:__main__:This is log entry number 611.
# DEBUG:__main__:This is log entry number 612.
# DEBUG:__main__:This is log entry number 613.
# DEBUG:__main__:This is log entry number 614.
# DEBUG:__main__:This is log entry number 615.
# DEBUG:__main__:This is log entry number 616.
# DEBUG:__main__:This is log entry number 617.
# DEBUG:__main__:This is log entry number 618.
# DEBUG:__main__:This is log entry number 619.
# DEBUG:__main__:This is log entry number 620.
# DEBUG:__main__:This is log entry number 621.
# DEBUG:__main__:This is log entry number 622.
# DEBUG:__main__:This is log entry number 623.
# DEBUG:__main__:This is log entry number 624.
# DEBUG:__main__:This is log entry number 625.
# DEBUG:__main__:This is log entry number 626.
# DEBUG:__main__:This is log entry number 627.
# DEBUG:__main__:This is log entry number 628.
# DEBUG:__main__:This is log entry number 629.
# DEBUG:__main__:This is log entry number 630.
# DEBUG:__main__:This is log entry number 631.
# DEBUG:__main__:This is log entry number 632.
# DEBUG:__main__:This is log entry number 633.
# DEBUG:__main__:This is log entry number 634.
# DEBUG:__main__:This is log entry number 635.
# DEBUG:__main__:This is log entry number 636.
# DEBUG:__main__:This is log entry number 637.
# DEBUG:__main__:This is log entry number 638.
# DEBUG:__main__:This is log entry number 639.
# DEBUG:__main__:This is log entry number 640.
# DEBUG:__main__:This is log entry number 641.
# DEBUG:__main__:This is log entry number 642.
# DEBUG:__main__:This is log entry number 643.
# DEBUG:__main__:This is log entry number 644.
# DEBUG:__main__:This is log entry number 645.
# DEBUG:__main__:This is log entry number 646.
# DEBUG:__main__:This is log entry number 647.
# DEBUG:__main__:This is log entry number 648.
# DEBUG:__main__:This is log entry number 649.
# DEBUG:__main__:This is log entry number 650.
# DEBUG:__main__:This is log entry number 651.
# DEBUG:__main__:This is log entry number 652.
# DEBUG:__main__:This is log entry number 653.
# DEBUG:__main__:This is log entry number 654.
# DEBUG:__main__:This is log entry number 655.
# DEBUG:__main__:This is log entry number 656.
# DEBUG:__main__:This is log entry number 657.
# DEBUG:__main__:This is log entry number 658.
# DEBUG:__main__:This is log entry number 659.
# DEBUG:__main__:This is log entry number 660.
# DEBUG:__main__:This is log entry number 661.
# DEBUG:__main__:This is log entry number 662.
# DEBUG:__main__:This is log entry number 663.
# DEBUG:__main__:This is log entry number 664.
# DEBUG:__main__:This is log entry number 665.
# DEBUG:__main__:This is log entry number 666.
# DEBUG:__main__:This is log entry number 667.
# DEBUG:__main__:This is log entry number 668.
# DEBUG:__main__:This is log entry number 669.
# DEBUG:__main__:This is log entry number 670.
# DEBUG:__main__:This is log entry number 671.
# DEBUG:__main__:This is log entry number 672.
# DEBUG:__main__:This is log entry number 673.
# DEBUG:__main__:This is log entry number 674.
# DEBUG:__main__:This is log entry number 675.
# DEBUG:__main__:This is log entry number 676.
# DEBUG:__main__:This is log entry number 677.
# DEBUG:__main__:This is log entry number 678.
# DEBUG:__main__:This is log entry number 679.
# DEBUG:__main__:This is log entry number 680.
# DEBUG:__main__:This is log entry number 681.
# DEBUG:__main__:This is log entry number 682.
# DEBUG:__main__:This is log entry number 683.
# DEBUG:__main__:This is log entry number 684.
# DEBUG:__main__:This is log entry number 685.
# DEBUG:__main__:This is log entry number 686.
# DEBUG:__main__:This is log entry number 687.
# DEBUG:__main__:This is log entry number 688.
# DEBUG:__main__:This is log entry number 689.
# DEBUG:__main__:This is log entry number 690.
# DEBUG:__main__:This is log entry number 691.
# DEBUG:__main__:This is log entry number 692.
# DEBUG:__main__:This is log entry number 693.
# DEBUG:__main__:This is log entry number 694.
# DEBUG:__main__:This is log entry number 695.
# DEBUG:__main__:This is log entry number 696.
# DEBUG:__main__:This is log entry number 697.
# DEBUG:__main__:This is log entry number 698.
# DEBUG:__main__:This is log entry number 699.
# DEBUG:__main__:This is log entry number 700.
# DEBUG:__main__:This is log entry number 701.
# DEBUG:__main__:This is log entry number 702.
# DEBUG:__main__:This is log entry number 703.
# DEBUG:__main__:This is log entry number 704.
# DEBUG:__main__:This is log entry number 705.
# DEBUG:__main__:This is log entry number 706.
# DEBUG:__main__:This is log entry number 707.
# DEBUG:__main__:This is log entry number 708.
# DEBUG:__main__:This is log entry number 709.
# DEBUG:__main__:This is log entry number 710.
# DEBUG:__main__:This is log entry number 711.
# DEBUG:__main__:This is log entry number 712.
# DEBUG:__main__:This is log entry number 713.
# DEBUG:__main__:This is log entry number 714.
# DEBUG:__main__:This is log entry number 715.
# DEBUG:__main__:This is log entry number 716.
# DEBUG:__main__:This is log entry number 717.
# DEBUG:__main__:This is log entry number 718.
# DEBUG:__main__:This is log entry number 719.
# DEBUG:__main__:This is log entry number 720.
# DEBUG:__main__:This is log entry number 721.
# DEBUG:__main__:This is log entry number 722.
# DEBUG:__main__:This is log entry number 723.
# DEBUG:__main__:This is log entry number 724.
# DEBUG:__main__:This is log entry number 725.
# DEBUG:__main__:This is log entry number 726.
# DEBUG:__main__:This is log entry number 727.
# DEBUG:__main__:This is log entry number 728.
# DEBUG:__main__:This is log entry number 729.
# DEBUG:__main__:This is log entry number 730.
# DEBUG:__main__:This is log entry number 731.
# DEBUG:__main__:This is log entry number 732.
# DEBUG:__main__:This is log entry number 733.
# DEBUG:__main__:This is log entry number 734.
# DEBUG:__main__:This is log entry number 735.
# DEBUG:__main__:This is log entry number 736.
# DEBUG:__main__:This is log entry number 737.
# DEBUG:__main__:This is log entry number 738.
# DEBUG:__main__:This is log entry number 739.
# DEBUG:__main__:This is log entry number 740.
# DEBUG:__main__:This is log entry number 741.
# DEBUG:__main__:This is log entry number 742.
# DEBUG:__main__:This is log entry number 743.
# DEBUG:__main__:This is log entry number 744.
# DEBUG:__main__:This is log entry number 745.
# DEBUG:__main__:This is log entry number 746.
# DEBUG:__main__:This is log entry number 747.
# DEBUG:__main__:This is log entry number 748.
# DEBUG:__main__:This is log entry number 749.
# DEBUG:__main__:This is log entry number 750.
# DEBUG:__main__:This is log entry number 751.
# DEBUG:__main__:This is log entry number 752.
# DEBUG:__main__:This is log entry number 753.
# DEBUG:__main__:This is log entry number 754.
# DEBUG:__main__:This is log entry number 755.
# DEBUG:__main__:This is log entry number 756.
# DEBUG:__main__:This is log entry number 757.
# DEBUG:__main__:This is log entry number 758.
# DEBUG:__main__:This is log entry number 759.
# DEBUG:__main__:This is log entry number 760.
# DEBUG:__main__:This is log entry number 761.
# DEBUG:__main__:This is log entry number 762.
# DEBUG:__main__:This is log entry number 763.
# DEBUG:__main__:This is log entry number 764.
# DEBUG:__main__:This is log entry number 765.
# DEBUG:__main__:This is log entry number 766.
# DEBUG:__main__:This is log entry number 767.
# DEBUG:__main__:This is log entry number 768.
# DEBUG:__main__:This is log entry number 769.
# DEBUG:__main__:This is log entry number 770.
# DEBUG:__main__:This is log entry number 771.
# DEBUG:__main__:This is log entry number 772.
# DEBUG:__main__:This is log entry number 773.
# DEBUG:__main__:This is log entry number 774.
# DEBUG:__main__:This is log entry number 775.
# DEBUG:__main__:This is log entry number 776.
# DEBUG:__main__:This is log entry number 777.
# DEBUG:__main__:This is log entry number 778.
# DEBUG:__main__:This is log entry number 779.
# DEBUG:__main__:This is log entry number 780.
# DEBUG:__main__:This is log entry number 781.
# DEBUG:__main__:This is log entry number 782.
# DEBUG:__main__:This is log entry number 783.
# DEBUG:__main__:This is log entry number 784.
# DEBUG:__main__:This is log entry number 785.
# DEBUG:__main__:This is log entry number 786.
# DEBUG:__main__:This is log entry number 787.
# DEBUG:__main__:This is log entry number 788.
# DEBUG:__main__:This is log entry number 789.
# DEBUG:__main__:This is log entry number 790.
# DEBUG:__main__:This is log entry number 791.
# DEBUG:__main__:This is log entry number 792.
# DEBUG:__main__:This is log entry number 793.
# DEBUG:__main__:This is log entry number 794.
# DEBUG:__main__:This is log entry number 795.
# DEBUG:__main__:This is log entry number 796.
# DEBUG:__main__:This is log entry number 797.
# DEBUG:__main__:This is log entry number 798.
# DEBUG:__main__:This is log entry number 799.
# DEBUG:__main__:This is log entry number 800.
# DEBUG:__main__:This is log entry number 801.
# DEBUG:__main__:This is log entry number 802.
# DEBUG:__main__:This is log entry number 803.
# DEBUG:__main__:This is log entry number 804.
# DEBUG:__main__:This is log entry number 805.
# DEBUG:__main__:This is log entry number 806.
# DEBUG:__main__:This is log entry number 807.
# DEBUG:__main__:This is log entry number 808.
# DEBUG:__main__:This is log entry number 809.
# DEBUG:__main__:This is log entry number 810.
# DEBUG:__main__:This is log entry number 811.
# DEBUG:__main__:This is log entry number 812.
# DEBUG:__main__:This is log entry number 813.
# DEBUG:__main__:This is log entry number 814.
# DEBUG:__main__:This is log entry number 815.
# DEBUG:__main__:This is log entry number 816.
# DEBUG:__main__:This is log entry number 817.
# DEBUG:__main__:This is log entry number 818.
# DEBUG:__main__:This is log entry number 819.
# DEBUG:__main__:This is log entry number 820.
# DEBUG:__main__:This is log entry number 821.
# DEBUG:__main__:This is log entry number 822.
# DEBUG:__main__:This is log entry number 823.
# DEBUG:__main__:This is log entry number 824.
# DEBUG:__main__:This is log entry number 825.
# DEBUG:__main__:This is log entry number 826.
# DEBUG:__main__:This is log entry number 827.
# DEBUG:__main__:This is log entry number 828.
# DEBUG:__main__:This is log entry number 829.
# DEBUG:__main__:This is log entry number 830.
# DEBUG:__main__:This is log entry number 831.
# DEBUG:__main__:This is log entry number 832.
# DEBUG:__main__:This is log entry number 833.
# DEBUG:__main__:This is log entry number 834.
# DEBUG:__main__:This is log entry number 835.
# DEBUG:__main__:This is log entry number 836.
# DEBUG:__main__:This is log entry number 837.
# DEBUG:__main__:This is log entry number 838.
# DEBUG:__main__:This is log entry number 839.
# DEBUG:__main__:This is log entry number 840.
# DEBUG:__main__:This is log entry number 841.
# DEBUG:__main__:This is log entry number 842.
# DEBUG:__main__:This is log entry number 843.
# DEBUG:__main__:This is log entry number 844.
# DEBUG:__main__:This is log entry number 845.
# DEBUG:__main__:This is log entry number 846.
# DEBUG:__main__:This is log entry number 847.
# DEBUG:__main__:This is log entry number 848.
# DEBUG:__main__:This is log entry number 849.
# DEBUG:__main__:This is log entry number 850.
# DEBUG:__main__:This is log entry number 851.
# DEBUG:__main__:This is log entry number 852.
# DEBUG:__main__:This is log entry number 853.
# DEBUG:__main__:This is log entry number 854.
# DEBUG:__main__:This is log entry number 855.
# DEBUG:__main__:This is log entry number 856.
# DEBUG:__main__:This is log entry number 857.
# DEBUG:__main__:This is log entry number 858.
# DEBUG:__main__:This is log entry number 859.
# DEBUG:__main__:This is log entry number 860.
# DEBUG:__main__:This is log entry number 861.
# DEBUG:__main__:This is log entry number 862.
# DEBUG:__main__:This is log entry number 863.
# DEBUG:__main__:This is log entry number 864.
# DEBUG:__main__:This is log entry number 865.
# DEBUG:__main__:This is log entry number 866.
# DEBUG:__main__:This is log entry number 867.
# DEBUG:__main__:This is log entry number 868.
# DEBUG:__main__:This is log entry number 869.
# DEBUG:__main__:This is log entry number 870.
# DEBUG:__main__:This is log entry number 871.
# DEBUG:__main__:This is log entry number 872.
# DEBUG:__main__:This is log entry number 873.
# DEBUG:__main__:This is log entry number 874.
# DEBUG:__main__:This is log entry number 875.
# DEBUG:__main__:This is log entry number 876.
# DEBUG:__main__:This is log entry number 877.
# DEBUG:__main__:This is log entry number 878.
# DEBUG:__main__:This is log entry number 879.
# DEBUG:__main__:This is log entry number 880.
# DEBUG:__main__:This is log entry number 881.
# DEBUG:__main__:This is log entry number 882.
# DEBUG:__main__:This is log entry number 883.
# DEBUG:__main__:This is log entry number 884.
# DEBUG:__main__:This is log entry number 885.
# DEBUG:__main__:This is log entry number 886.
# DEBUG:__main__:This is log entry number 887.
# DEBUG:__main__:This is log entry number 888.
# DEBUG:__main__:This is log entry number 889.
# DEBUG:__main__:This is log entry number 890.
# DEBUG:__main__:This is log entry number 891.
# DEBUG:__main__:This is log entry number 892.
# DEBUG:__main__:This is log entry number 893.
# DEBUG:__main__:This is log entry number 894.
# DEBUG:__main__:This is log entry number 895.
# DEBUG:__main__:This is log entry number 896.
# DEBUG:__main__:This is log entry number 897.
# DEBUG:__main__:This is log entry number 898.
# DEBUG:__main__:This is log entry number 899.
# DEBUG:__main__:This is log entry number 900.
# DEBUG:__main__:This is log entry number 901.
# DEBUG:__main__:This is log entry number 902.
# DEBUG:__main__:This is log entry number 903.
# DEBUG:__main__:This is log entry number 904.
# DEBUG:__main__:This is log entry number 905.
# DEBUG:__main__:This is log entry number 906.
# DEBUG:__main__:This is log entry number 907.
# DEBUG:__main__:This is log entry number 908.
# DEBUG:__main__:This is log entry number 909.
# DEBUG:__main__:This is log entry number 910.
# DEBUG:__main__:This is log entry number 911.
# DEBUG:__main__:This is log entry number 912.
# DEBUG:__main__:This is log entry number 913.
# DEBUG:__main__:This is log entry number 914.
# DEBUG:__main__:This is log entry number 915.
# DEBUG:__main__:This is log entry number 916.
# DEBUG:__main__:This is log entry number 917.
# DEBUG:__main__:This is log entry number 918.
# DEBUG:__main__:This is log entry number 919.
# DEBUG:__main__:This is log entry number 920.
# DEBUG:__main__:This is log entry number 921.
# DEBUG:__main__:This is log entry number 922.
# DEBUG:__main__:This is log entry number 923.
# DEBUG:__main__:This is log entry number 924.
# DEBUG:__main__:This is log entry number 925.
# DEBUG:__main__:This is log entry number 926.
# DEBUG:__main__:This is log entry number 927.
# DEBUG:__main__:This is log entry number 928.
# DEBUG:__main__:This is log entry number 929.
# DEBUG:__main__:This is log entry number 930.
# DEBUG:__main__:This is log entry number 931.
# DEBUG:__main__:This is log entry number 932.
# DEBUG:__main__:This is log entry number 933.
# DEBUG:__main__:This is log entry number 934.
# DEBUG:__main__:This is log entry number 935.
# DEBUG:__main__:This is log entry number 936.
# DEBUG:__main__:This is log entry number 937.
# DEBUG:__main__:This is log entry number 938.
# DEBUG:__main__:This is log entry number 939.
# DEBUG:__main__:This is log entry number 940.
# DEBUG:__main__:This is log entry number 941.
# DEBUG:__main__:This is log entry number 942.
# DEBUG:__main__:This is log entry number 943.
# DEBUG:__main__:This is log entry number 944.
# DEBUG:__main__:This is log entry number 945.
# DEBUG:__main__:This is log entry number 946.
# DEBUG:__main__:This is log entry number 947.
# DEBUG:__main__:This is log entry number 948.
# DEBUG:__main__:This is log entry number 949.
# DEBUG:__main__:This is log entry number 950.
# DEBUG:__main__:This is log entry number 951.
# DEBUG:__main__:This is log entry number 952.
# DEBUG:__main__:This is log entry number 953.
# DEBUG:__main__:This is log entry number 954.
# DEBUG:__main__:This is log entry number 955.
# DEBUG:__main__:This is log entry number 956.
# DEBUG:__main__:This is log entry number 957.
# DEBUG:__main__:This is log entry number 958.
# DEBUG:__main__:This is log entry number 959.
# DEBUG:__main__:This is log entry number 960.
# DEBUG:__main__:This is log entry number 961.
# DEBUG:__main__:This is log entry number 962.
# DEBUG:__main__:This is log entry number 963.
# DEBUG:__main__:This is log entry number 964.
# DEBUG:__main__:This is log entry number 965.
# DEBUG:__main__:This is log entry number 966.
# DEBUG:__main__:This is log entry number 967.
# DEBUG:__main__:This is log entry number 968.
# DEBUG:__main__:This is log entry number 969.
# DEBUG:__main__:This is log entry number 970.
# DEBUG:__main__:This is log entry number 971.
# DEBUG:__main__:This is log entry number 972.
# DEBUG:__main__:This is log entry number 973.
# DEBUG:__main__:This is log entry number 974.
# DEBUG:__main__:This is log entry number 975.
# DEBUG:__main__:This is log entry number 976.
# DEBUG:__main__:This is log entry number 977.
# DEBUG:__main__:This is log entry number 978.
# DEBUG:__main__:This is log entry number 979.
# DEBUG:__main__:This is log entry number 980.
# DEBUG:__main__:This is log entry number 981.
# DEBUG:__main__:This is log entry number 982.
# DEBUG:__main__:This is log entry number 983.
# DEBUG:__main__:This is log entry number 984.
# DEBUG:__main__:This is log entry number 985.
# DEBUG:__main__:This is log entry number 986.
# DEBUG:__main__:This is log entry number 987.
# DEBUG:__main__:This is log entry number 988.
# DEBUG:__main__:This is log entry number 989.
# DEBUG:__main__:This is log entry number 990.
# DEBUG:__main__:This is log entry number 991.
# DEBUG:__main__:This is log entry number 992.
# DEBUG:__main__:This is log entry number 993.
# DEBUG:__main__:This is log entry number 994.
# DEBUG:__main__:This is log entry number 995.
# DEBUG:__main__:This is log entry number 996.
# DEBUG:__main__:This is log entry number 997.
# DEBUG:__main__:This is log entry number 998.
# DEBUG:__main__:This is log entry number 999.
# DEBUG:__main__:This is log entry number 1000.
# DEBUG:__main__:This is log entry number 1001.
# DEBUG:__main__:This is log entry number 1002.
# DEBUG:__main__:This is log entry number 1003.
# DEBUG:__main__:This is log entry number 1004.
# DEBUG:__main__:This is log entry number 1005.
# DEBUG:__main__:This is log entry number 1006.
# DEBUG:__main__:This is log entry number 1007.
# DEBUG:__main__:This is log entry number 1008.
# DEBUG:__main__:This is log entry number 1009.
# DEBUG:__main__:This is log entry number 1010.
# DEBUG:__main__:This is log entry number 1011.
# DEBUG:__main__:This is log entry number 1012.
# DEBUG:__main__:This is log entry number 1013.
# DEBUG:__main__:This is log entry number 1014.
# DEBUG:__main__:This is log entry number 1015.
# DEBUG:__main__:This is log entry number 1016.
# DEBUG:__main__:This is log entry number 1017.
# DEBUG:__main__:This is log entry number 1018.
# DEBUG:__main__:This is log entry number 1019.
# DEBUG:__main__:This is log entry number 1020.
# DEBUG:__main__:This is log entry number 1021.
# DEBUG:__main__:This is log entry number 1022.
# DEBUG:__main__:This is log entry number 1023.
# DEBUG:__main__:This is log entry number 1024.
# DEBUG:__main__:This is log entry number 1025.
# DEBUG:__main__:This is log entry number 1026.
# DEBUG:__main__:This is log entry number 1027.
# DEBUG:__main__:This is log entry number 1028.
# DEBUG:__main__:This is log entry number 1029.
# DEBUG:__main__:This is log entry number 1030.
# DEBUG:__main__:This is log entry number 1031.
# DEBUG:__main__:This is log entry number 1032.
# DEBUG:__main__:This is log entry number 1033.
# DEBUG:__main__:This is log entry number 1034.
# DEBUG:__main__:This is log entry number 1035.
# DEBUG:__main__:This is log entry number 1036.
# DEBUG:__main__:This is log entry number 1037.
# DEBUG:__main__:This is log entry number 1038.
# DEBUG:__main__:This is log entry number 1039.
# DEBUG:__main__:This is log entry number 1040.
# DEBUG:__main__:This is log entry number 1041.
# DEBUG:__main__:This is log entry number 1042.
# DEBUG:__main__:This is log entry number 1043.
# DEBUG:__main__:This is log entry number 1044.
# DEBUG:__main__:This is log entry number 1045.
# DEBUG:__main__:This is log entry number 1046.
# DEBUG:__main__:This is log entry number 1047.
# DEBUG:__main__:This is log entry number 1048.
# DEBUG:__main__:This is log entry number 1049.
# DEBUG:__main__:This is log entry number 1050.
# DEBUG:__main__:This is log entry number 1051.
# DEBUG:__main__:This is log entry number 1052.
# DEBUG:__main__:This is log entry number 1053.
# DEBUG:__main__:This is log entry number 1054.
# DEBUG:__main__:This is log entry number 1055.
# DEBUG:__main__:This is log entry number 1056.
# DEBUG:__main__:This is log entry number 1057.
# DEBUG:__main__:This is log entry number 1058.
# DEBUG:__main__:This is log entry number 1059.
# DEBUG:__main__:This is log entry number 1060.
# DEBUG:__main__:This is log entry number 1061.
# DEBUG:__main__:This is log entry number 1062.
# ...
# DEBUG:__main__:This is log entry number 1654.
# DEBUG:__main__:This is log entry number 1655.
# DEBUG:__main__:This is log entry number 1656.
# DEBUG:__main__:This is log entry number 1657.
# DEBUG:__main__:This is log entry number 1658.
# DEBUG:__main__:This is log entry number 1659.
# DEBUG:__main__:This is log entry number 1660.
# DEBUG:__main__:This is log entry number 1661.
# DEBUG:__main__:This is log entry number 1662.
# DEBUG:__main__:This is log entry number 1663.
# DEBUG:__main__:This is log entry number 1664.
# DEBUG:__main__:This is log entry number 1665.
# DEBUG:__main__:This is log entry number 1666.
# DEBUG:__main__:This is log entry number 1667.
# DEBUG:__main__:This is log entry number 1668.
# DEBUG:__main__:This is log entry number 1669.
# DEBUG:__main__:This is log entry number 1670.
# DEBUG:__main__:This is log entry number 1671.
# DEBUG:__main__:This is log entry number 1672.
# DEBUG:__main__:This is log entry number 1673.
# DEBUG:__main__:This is log entry number 1674.
# DEBUG:__main__:This is log entry number 1675.
# DEBUG:__main__:This is log entry number 1676.
# DEBUG:__main__:This is log entry number 1677.
# DEBUG:__main__:This is log entry number 1678.
# DEBUG:__main__:This is log entry number 1679.
# DEBUG:__main__:This is log entry number 1680.
# DEBUG:__main__:This is log entry number 1681.
# DEBUG:__main__:This is log entry number 1682.
# DEBUG:__main__:This is log entry number 1683.
# DEBUG:__main__:This is log entry number 1684.
# DEBUG:__main__:This is log entry number 1685.
# DEBUG:__main__:This is log entry number 1686.
# DEBUG:__main__:This is log entry number 1687.
# DEBUG:__main__:This is log entry number 1688.
# DEBUG:__main__:This is log entry number 1689.
# DEBUG:__main__:This is log entry number 1690.
# DEBUG:__main__:This is log entry number 1691.
# DEBUG:__main__:This is log entry number 1692.
# DEBUG:__main__:This is log entry number 1693.
# DEBUG:__main__:This is log entry number 1694.
# DEBUG:__main__:This is log entry number 1695.
# DEBUG:__main__:This is log entry number 1696.
# DEBUG:__main__:This is log entry number 1697.
# DEBUG:__main__:This is log entry number 1698.
# DEBUG:__main__:This is log entry number 1699.
# DEBUG:__main__:This is log entry number 1700.
# DEBUG:__main__:This is log entry number 1701.
# DEBUG:__main__:This is log entry number 1702.
# DEBUG:__main__:This is log entry number 1703.
# DEBUG:__main__:This is log entry number 1704.
# DEBUG:__main__:This is log entry number 1705.
# DEBUG:__main__:This is log entry number 1706.
# DEBUG:__main__:This is log entry number 1707.
# DEBUG:__main__:This is log entry number 1708.
# DEBUG:__main__:This is log entry number 1709.
# DEBUG:__main__:This is log entry number 1710.
# DEBUG:__main__:This is log entry number 1711.
# DEBUG:__main__:This is log entry number 1712.
# DEBUG:__main__:This is log entry number 1713.
# DEBUG:__main__:This is log entry number 1714.
# DEBUG:__main__:This is log entry number 1715.
# DEBUG:__main__:This is log entry number 1716.
# DEBUG:__main__:This is log entry number 1717.
# DEBUG:__main__:This is log entry number 1718.
# DEBUG:__main__:This is log entry number 1719.
# DEBUG:__main__:This is log entry number 1720.
# DEBUG:__main__:This is log entry number 1721.
# DEBUG:__main__:This is log entry number 1722.
# DEBUG:__main__:This is log entry number 1723.
# DEBUG:__main__:This is log entry number 1724.
# DEBUG:__main__:This is log entry number 1725.
# DEBUG:__main__:This is log entry number 1726.
# DEBUG:__main__:This is log entry number 1727.
# DEBUG:__main__:This is log entry number 1728.
# DEBUG:__main__:This is log entry number 1729.
# DEBUG:__main__:This is log entry number 1730.
# DEBUG:__main__:This is log entry number 1731.
# DEBUG:__main__:This is log entry number 1732.
# DEBUG:__main__:This is log entry number 1733.
# DEBUG:__main__:This is log entry number 1734.
# DEBUG:__main__:This is log entry number 1735.
# DEBUG:__main__:This is log entry number 1736.
# DEBUG:__main__:This is log entry number 1737.
# DEBUG:__main__:This is log entry number 1738.
# DEBUG:__main__:This is log entry number 1739.
# DEBUG:__main__:This is log entry number 1740.
# DEBUG:__main__:This is log entry number 1741.
# DEBUG:__main__:This is log entry number 1742.
# DEBUG:__main__:This is log entry number 1743.
# DEBUG:__main__:This is log entry number 1744.
# DEBUG:__main__:This is log entry number 1745.
# DEBUG:__main__:This is log entry number 1746.
# DEBUG:__main__:This is log entry number 1747.
# DEBUG:__main__:This is log entry number 1748.
# DEBUG:__main__:This is log entry number 1749.
# DEBUG:__main__:This is log entry number 1750.
# DEBUG:__main__:This is log entry number 1751.
# DEBUG:__main__:This is log entry number 1752.
# DEBUG:__main__:This is log entry number 1753.
# DEBUG:__main__:This is log entry number 1754.
# DEBUG:__main__:This is log entry number 1755.
# DEBUG:__main__:This is log entry number 1756.
# DEBUG:__main__:This is log entry number 1757.
# DEBUG:__main__:This is log entry number 1758.
# DEBUG:__main__:This is log entry number 1759.
# DEBUG:__main__:This is log entry number 1760.
# DEBUG:__main__:This is log entry number 1761.
# DEBUG:__main__:This is log entry number 1762.
# DEBUG:__main__:This is log entry number 1763.
# DEBUG:__main__:This is log entry number 1764.
# DEBUG:__main__:This is log entry number 1765.
# DEBUG:__main__:This is log entry number 1766.
# DEBUG:__main__:This is log entry number 1767.
# DEBUG:__main__:This is log entry number 1768.
# DEBUG:__main__:This is log entry number 1769.
# DEBUG:__main__:This is log entry number 1770.
# DEBUG:__main__:This is log entry number 1771.
# DEBUG:__main__:This is log entry number 1772.
# DEBUG:__main__:This is log entry number 1773.
# DEBUG:__main__:This is log entry number 1774.
# DEBUG:__main__:This is log entry number 1775.
# DEBUG:__main__:This is log entry number 1776.
# DEBUG:__main__:This is log entry number 1777.
# DEBUG:__main__:This is log entry number 1778.
# DEBUG:__main__:This is log entry number 1779.
# DEBUG:__main__:This is log entry number 1780.
# DEBUG:__main__:This is log entry number 1781.
# DEBUG:__main__:This is log entry number 1782.
# DEBUG:__main__:This is log entry number 1783.
# DEBUG:__main__:This is log entry number 1784.
# DEBUG:__main__:This is log entry number 1785.
# DEBUG:__main__:This is log entry number 1786.
# DEBUG:__main__:This is log entry number 1787.
# DEBUG:__main__:This is log entry number 1788.
# DEBUG:__main__:This is log entry number 1789.
# DEBUG:__main__:This is log entry number 1790.
# DEBUG:__main__:This is log entry number 1791.
# DEBUG:__main__:This is log entry number 1792.
# DEBUG:__main__:This is log entry number 1793.
# DEBUG:__main__:This is log entry number 1794.
# DEBUG:__main__:This is log entry number 1795.
# DEBUG:__main__:This is log entry number 1796.
# DEBUG:__main__:This is log entry number 1797.
# DEBUG:__main__:This is log entry number 1798.
# DEBUG:__main__:This is log entry number 1799.
# DEBUG:__main__:This is log entry number 1800.
# DEBUG:__main__:This is log entry number 1801.
# DEBUG:__main__:This is log entry number 1802.
# DEBUG:__main__:This is log entry number 1803.
# DEBUG:__main__:This is log entry number 1804.
# DEBUG:__main__:This is log entry number 1805.
# DEBUG:__main__:This is log entry number 1806.
# DEBUG:__main__:This is log entry number 1807.
# DEBUG:__main__:This is log entry number 1808.
# DEBUG:__main__:This is log entry number 1809.
# DEBUG:__main__:This is log entry number 1810.
# DEBUG:__main__:This is log entry number 1811.
# DEBUG:__main__:This is log entry number 1812.
# DEBUG:__main__:This is log entry number 1813.
# DEBUG:__main__:This is log entry number 1814.
# DEBUG:__main__:This is log entry number 1815.
# DEBUG:__main__:This is log entry number 1816.
# DEBUG:__main__:This is log entry number 1817.
# DEBUG:__main__:This is log entry number 1818.
# DEBUG:__main__:This is log entry number 1819.
# DEBUG:__main__:This is log entry number 1820.
# DEBUG:__main__:This is log entry number 1821.
# DEBUG:__main__:This is log entry number 1822.
# DEBUG:__main__:This is log entry number 1823.
# DEBUG:__main__:This is log entry number 1824.
# DEBUG:__main__:This is log entry number 1825.
# DEBUG:__main__:This is log entry number 1826.
# DEBUG:__main__:This is log entry number 1827.
# DEBUG:__main__:This is log entry number 1828.
# DEBUG:__main__:This is log entry number 1829.
# DEBUG:__main__:This is log entry number 1830.
# DEBUG:__main__:This is log entry number 1831.
# DEBUG:__main__:This is log entry number 1832.
# DEBUG:__main__:This is log entry number 1833.
# DEBUG:__main__:This is log entry number 1834.
# DEBUG:__main__:This is log entry number 1835.
# DEBUG:__main__:This is log entry number 1836.
# DEBUG:__main__:This is log entry number 1837.
# DEBUG:__main__:This is log entry number 1838.
# DEBUG:__main__:This is log entry number 1839.
# DEBUG:__main__:This is log entry number 1840.
# DEBUG:__main__:This is log entry number 1841.
# DEBUG:__main__:This is log entry number 1842.
# DEBUG:__main__:This is log entry number 1843.
# DEBUG:__main__:This is log entry number 1844.
# DEBUG:__main__:This is log entry number 1845.
# DEBUG:__main__:This is log entry number 1846.
# DEBUG:__main__:This is log entry number 1847.
# DEBUG:__main__:This is log entry number 1848.
# DEBUG:__main__:This is log entry number 1849.
# DEBUG:__main__:This is log entry number 1850.
# DEBUG:__main__:This is log entry number 1851.
# DEBUG:__main__:This is log entry number 1852.
# DEBUG:__main__:This is log entry number 1853.
# DEBUG:__main__:This is log entry number 1854.
# DEBUG:__main__:This is log entry number 1855.
# DEBUG:__main__:This is log entry number 1856.
# DEBUG:__main__:This is log entry number 1857.
# DEBUG:__main__:This is log entry number 1858.
# DEBUG:__main__:This is log entry number 1859.
# DEBUG:__main__:This is log entry number 1860.
# DEBUG:__main__:This is log entry number 1861.
# DEBUG:__main__:This is log entry number 1862.
# DEBUG:__main__:This is log entry number 1863.
# DEBUG:__main__:This is log entry number 1864.
# DEBUG:__main__:This is log entry number 1865.
# DEBUG:__main__:This is log entry number 1866.
# DEBUG:__main__:This is log entry number 1867.
# DEBUG:__main__:This is log entry number 1868.
# DEBUG:__main__:This is log entry number 1869.
# DEBUG:__main__:This is log entry number 1870.
# DEBUG:__main__:This is log entry number 1871.
# DEBUG:__main__:This is log entry number 1872.
# DEBUG:__main__:This is log entry number 1873.
# DEBUG:__main__:This is log entry number 1874.
# DEBUG:__main__:This is log entry number 1875.
# DEBUG:__main__:This is log entry number 1876.
# DEBUG:__main__:This is log entry number 1877.
# DEBUG:__main__:This is log entry number 1878.
# DEBUG:__main__:This is log entry number 1879.
# DEBUG:__main__:This is log entry number 1880.
# DEBUG:__main__:This is log entry number 1881.
# DEBUG:__main__:This is log entry number 1882.
# DEBUG:__main__:This is log entry number 1883.
# DEBUG:__main__:This is log entry number 1884.
# DEBUG:__main__:This is log entry number 1885.
# DEBUG:__main__:This is log entry number 1886.
# DEBUG:__main__:This is log entry number 1887.
# DEBUG:__main__:This is log entry number 1888.
# DEBUG:__main__:This is log entry number 1889.
# DEBUG:__main__:This is log entry number 1890.
# DEBUG:__main__:This is log entry number 1891.
# DEBUG:__main__:This is log entry number 1892.
# DEBUG:__main__:This is log entry number 1893.
# DEBUG:__main__:This is log entry number 1894.
# DEBUG:__main__:This is log entry number 1895.
# DEBUG:__main__:This is log entry number 1896.
# DEBUG:__main__:This is log entry number 1897.
# DEBUG:__main__:This is log entry number 1898.
# DEBUG:__main__:This is log entry number 1899.
# DEBUG:__main__:This is log entry number 1900.
# DEBUG:__main__:This is log entry number 1901.
# DEBUG:__main__:This is log entry number 1902.
# DEBUG:__main__:This is log entry number 1903.
# DEBUG:__main__:This is log entry number 1904.
# DEBUG:__main__:This is log entry number 1905.
# DEBUG:__main__:This is log entry number 1906.
# DEBUG:__main__:This is log entry number 1907.
# DEBUG:__main__:This is log entry number 1908.
# DEBUG:__main__:This is log entry number 1909.
# DEBUG:__main__:This is log entry number 1910.
# DEBUG:__main__:This is log entry number 1911.
# DEBUG:__main__:This is log entry number 1912.
# DEBUG:__main__:This is log entry number 1913.
# DEBUG:__main__:This is log entry number 1914.
# DEBUG:__main__:This is log entry number 1915.
# DEBUG:__main__:This is log entry number 1916.
# DEBUG:__main__:This is log entry number 1917.
# DEBUG:__main__:This is log entry number 1918.
# DEBUG:__main__:This is log entry number 1919.
# DEBUG:__main__:This is log entry number 1920.
# DEBUG:__main__:This is log entry number 1921.
# DEBUG:__main__:This is log entry number 1922.
# DEBUG:__main__:This is log entry number 1923.
# DEBUG:__main__:This is log entry number 1924.
# DEBUG:__main__:This is log entry number 1925.
# DEBUG:__main__:This is log entry number 1926.
# DEBUG:__main__:This is log entry number 1927.
# DEBUG:__main__:This is log entry number 1928.
# DEBUG:__main__:This is log entry number 1929.
# DEBUG:__main__:This is log entry number 1930.
# DEBUG:__main__:This is log entry number 1931.
# DEBUG:__main__:This is log entry number 1932.
# DEBUG:__main__:This is log entry number 1933.
# DEBUG:__main__:This is log entry number 1934.
# DEBUG:__main__:This is log entry number 1935.
# DEBUG:__main__:This is log entry number 1936.
# DEBUG:__main__:This is log entry number 1937.
# DEBUG:__main__:This is log entry number 1938.
# DEBUG:__main__:This is log entry number 1939.
# DEBUG:__main__:This is log entry number 1940.
# DEBUG:__main__:This is log entry number 1941.
# DEBUG:__main__:This is log entry number 1942.
# DEBUG:__main__:This is log entry number 1943.
# DEBUG:__main__:This is log entry number 1944.
# DEBUG:__main__:This is log entry number 1945.
# DEBUG:__main__:This is log entry number 1946.
# DEBUG:__main__:This is log entry number 1947.
# DEBUG:__main__:This is log entry number 1948.
# DEBUG:__main__:This is log entry number 1949.
# DEBUG:__main__:This is log entry number 1950.
# DEBUG:__main__:This is log entry number 1951.
# DEBUG:__main__:This is log entry number 1952.
# DEBUG:__main__:This is log entry number 1953.
# DEBUG:__main__:This is log entry number 1954.
# DEBUG:__main__:This is log entry number 1955.
# DEBUG:__main__:This is log entry number 1956.
# DEBUG:__main__:This is log entry number 1957.
# DEBUG:__main__:This is log entry number 1958.
# DEBUG:__main__:This is log entry number 1959.
# DEBUG:__main__:This is log entry number 1960.
# DEBUG:__main__:This is log entry number 1961.
# DEBUG:__main__:This is log entry number 1962.
# DEBUG:__main__:This is log entry number 1963.
# DEBUG:__main__:This is log entry number 1964.
# DEBUG:__main__:This is log entry number 1965.
# DEBUG:__main__:This is log entry number 1966.
# DEBUG:__main__:This is log entry number 1967.
# DEBUG:__main__:This is log entry number 1968.
# DEBUG:__main__:This is log entry number 1969.
# DEBUG:__main__:This is log entry number 1970.
# DEBUG:__main__:This is log entry number 1971.
# DEBUG:__main__:This is log entry number 1972.
# DEBUG:__main__:This is log entry number 1973.
# DEBUG:__main__:This is log entry number 1974.
# DEBUG:__main__:This is log entry number 1975.
# DEBUG:__main__:This is log entry number 1976.
# DEBUG:__main__:This is log entry number 1977.
# DEBUG:__main__:This is log entry number 1978.
# DEBUG:__main__:This is log entry number 1979.
# DEBUG:__main__:This is log entry number 1980.
# DEBUG:__main__:This is log entry number 1981.
# DEBUG:__main__:This is log entry number 1982.
# DEBUG:__main__:This is log entry number 1983.
# DEBUG:__main__:This is log entry number 1984.
# DEBUG:__main__:This is log entry number 1985.
# DEBUG:__main__:This is log entry number 1986.
# DEBUG:__main__:This is log entry number 1987.
# DEBUG:__main__:This is log entry number 1988.
# DEBUG:__main__:This is log entry number 1989.
# DEBUG:__main__:This is log entry number 1990.
# DEBUG:__main__:This is log entry number 1991.
# DEBUG:__main__:This is log entry number 1992.
# DEBUG:__main__:This is log entry number 1993.
# DEBUG:__main__:This is log entry number 1994.
# DEBUG:__main__:This is log entry number 1995.
# DEBUG:__main__:This is log entry number 1996.
# DEBUG:__main__:This is log entry number 1997.
# DEBUG:__main__:This is log entry number 1998.
# DEBUG:__main__:This is log entry number 1999.
# DEBUG:__main__:This is log entry number 2000.

# %%
#Ques19:Write a program that handles both IndexError and KeyError using a try-except block?
data = [1, 2, 3]
my_dict = {"a": 1, "b": 2, "c": 3}

try:
    index = int(input("Enter an index for the list: "))
    value = data[index]
    print(f"Value at index {index}: {value}")

    key = input("Enter a key for the dictionary: ")
    dict_value = my_dict[key]
    print(f"Value for key '{key}': {dict_value}")

except IndexError:
    print("Error: Index out of range.")
except KeyError:
    print("Error: Key not found in dictionary.")
except ValueError:
    print("Error: Invalid input. Please enter an integer for the index.")
# Out:
# Enter an index for the list: 3
# Error: Index out of range.

# %%
#Ques20:How would you open a file and read its contents using a context manager in Python?
def read_file_with_context_manager(filename):
    try:
        with open(filename, 'r') as file:
            content = file.read()
            return content
    except FileNotFoundError:
        return f"Error: File '{filename}' not found."
    except Exception as e:
        return f"An error occurred: {e}"

file_content = read_file_with_context_manager('example.txt')
print(file_content)

# Example creating the file if it does not exists:
with open('example.txt', 'w') as file:
    file.write("Hello, World!")

file_content = read_file_with_context_manager('example.txt')
print(file_content)
# Out:
# Error: File 'example.txt' not found.
# Hello, World!

# %%
#Ques21:Write a Python program that reads a file and prints the number of occurrences of a specific word.
def count_word_occurrences(file_path, word_to_count):
    try:
        # Open the file in read mode
        with open(file_path, 'r', encoding='utf-8') as file:
            # Read the file content
            content = file.read()

        # Normalize the text to lowercase for case-insensitive matching
        content = content.lower()
        word_to_count = word_to_count.lower()

        # Split the content into words
        words = content.split()

        # Count the occurrences of the specific word
        count = words.count(word_to_count)

        print(f"The word '{word_to_count}' occurs {count} times in the file.")
    except FileNotFoundError:
        print("The specified file was not found. Please check the file path.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
file_path = input("Enter the file path: ")
word_to_count = input("Enter the word to count: ")
count_word_occurrences(file_path, word_to_count)
# Out:
# Enter the file path: path
# Enter the word to count: 20
# The specified file was not found. Please check the file path.

# %%
#Ques22:How can you check if a file is empty before attempting to read its contents?
file_path = 'my_file.txt'
with open(file_path, 'r') as file_obj:
    first_char = file_obj.read(1)
    if not first_char:
        print("File is empty")
    else:
        print("File is NOT empty")
# Out:
# File is NOT empty

# %%
#Ques23:Write a Python program that writes to a log file when an error occurs during file handling.
import logging

# Configure logging to write to a file
logging.basicConfig(filename='file_handling_errors.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

def process_file(file_path):

    try:
        with open(file_path, 'r') as file:
            content = file.read()
        # Process the content (example: print it)
        print(content)
    except FileNotFoundError:
        logging.error(f"File not found: {file_path}")
    except PermissionError:
        logging.error(f"Permission denied for: {file_path}")
    except Exception as e:
        logging.error(f"An unexpected error occurred: {e}")

# Example usage:
file_path = 'example.txt'  # Replace with your file path
process_file(file_path)
# Out:
# Hello, World!
